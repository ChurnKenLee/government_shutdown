# %%
import pandas as pd
from pandas.api.types import union_categoricals
import numpy as np
from pathlib import Path
import pickle

# %%
# Load dicts of paths of binaries
with open('opm_dynamic_feather_path_dict.pkl', 'rb') as f:
    opm_dynamic_feather_path_dict = pickle.load(f)

with open('opm_status_feather_path_dict.pkl', 'rb') as f:
    opm_status_feather_path_dict = pickle.load(f)

# %%
opm_dynamic_cat_col_list = [
    'Agency/Subelement',
    'Accession/Separation Indicator',
    'Age',
    'Pay Plan',
    'Grade',
    'LOS Level',
    'Duty Station',
    'Occupation',
    'Type of Appointment',
    'Work Schedule'
    ]

# %%
opm_status_cat_col_list = [
    'Agency/Subelement',
    'Duty Station',
    'Age Range',
    'Education Level',
    'Pay Plan',
    'Grade',
    'LOS Level',
    'Occupation',
    'Occupational Category (PATCO)',
    'Supervisory Status',
    'Type of Appointment',
    'Work Schedule',
    'NSFTP Indicator'
    ]

# %%
# Store categorical variable map for each categorical variable and year in nested dict
opm_dynamic_cat_index_dict = {}
opm_status_cat_index_dict = {}

for col in opm_dynamic_cat_col_list:
    opm_dynamic_cat_index_dict[col] = {}

for col in opm_status_cat_col_list:
    opm_status_cat_index_dict[col] = {}

# %%
start_year = 1982
start_qtr = 1
end_year = 2014
end_qtr = 2

# %%
for year in range(start_year, end_year+1):
    for qtr in range(1, 5):
        if (year == start_year) and (qtr < start_qtr):
            continue
        if (year == end_year) and (qtr > end_qtr):
            continue

        df = pd.read_feather(opm_dynamic_feather_path_dict[(year, qtr)])

        for col in opm_dynamic_cat_col_list:
            cat_index = pd.CategoricalIndex(df[col])
            opm_dynamic_cat_index_dict[col][(year, qtr)] = cat_index

# %%
# Find the union across years of each categorical variable, and store resulting union in dict
opm_dynamic_uc_dict = {}
for col, cat_index_dict in opm_dynamic_cat_index_dict.items():
    opm_dynamic_uc_dict[col] = union_categoricals([cat_index for cat_index in cat_index_dict.values()])

# %%
start_year = 1973
start_qtr = 3
end_year = 2014
end_qtr = 2

# %%
for year in range(start_year, end_year+1):
    for qtr in range(1, 5):
        if (year == start_year) and (qtr < start_qtr):
            continue
        if (year == end_year) and (qtr > end_qtr):
            continue

        df = pd.read_feather(opm_status_feather_path_dict[(year, qtr)])

        for col in opm_status_cat_col_list:
            cat_index = pd.CategoricalIndex(df[col])
            opm_status_cat_index_dict[col][(year, qtr)] = cat_index
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\Users\churn_5stexhd\Documents\UCSD\Projects\government_shutdown\code\step_02_open_binaries.ipynb Cell 10' in <cell line: 1>()
#       <a href='vscode-notebook-cell:/c%3A/Users/churn_5stexhd/Documents/UCSD/Projects/government_shutdown/code/step_02_open_binaries.ipynb#ch0000033?line=4'>5</a> if (year == end_year) and (qtr > end_qtr):
#       <a href='vscode-notebook-cell:/c%3A/Users/churn_5stexhd/Documents/UCSD/Projects/government_shutdown/code/step_02_open_binaries.ipynb#ch0000033?line=5'>6</a>     continue
# ----> <a href='vscode-notebook-cell:/c%3A/Users/churn_5stexhd/Documents/UCSD/Projects/government_shutdown/code/step_02_open_binaries.ipynb#ch0000033?line=7'>8</a> df = pd.read_feather(opm_status_feather_path_dict[(year, qtr)])
#      <a href='vscode-notebook-cell:/c%3A/Users/churn_5stexhd/Documents/UCSD/Projects/government_shutdown/code/step_02_open_binaries.ipynb#ch0000033?line=9'>10</a> for col in opm_status_cat_col_list:
#      <a href='vscode-notebook-cell:/c%3A/Users/churn_5stexhd/Documents/UCSD/Projects/government_shutdown/code/step_02_open_binaries.ipynb#ch0000033?line=10'>11</a>     cat_index = pd.CategoricalIndex(df[col])
#
# KeyError: (1982, 1)

# %%
df[pd.Categorical(df[col], categories = cat_index2.categories).isna()]
# Out:
#        Pseudo-ID            Employee Name Agency/Subelement  \
# 2      003266340  NAME WITHHELD BY AGENCY              AGAW
# 3      008498052                 DUNN P A              AGAW
# 5877   007225620             CAMPBELL R D              AG98
# 5878   010064710         EDUARDO,AMELIA M              AG98
# 6139   003312946  NAME WITHHELD BY AGENCY              CF00
# 6140   002450215       ROBINSON,ARTESIA L              CG00
# 16632  001759941          ALLUM,JEFFREY R              DLNY
# 18233  000240928           KELLER DAVID B              EO00
# 18234  001328204         CHARLES JUDITH B              EO00
# 18235  002636645        KELLING,KRISTIN A              EO00
# 18236  003055415           CARTER,JERRY L              EO00
# 18237  004021207      SWEARINGEN VIVIAN E              EO00
# 18238  004021207      SWEARINGEN VIVIAN E              EO00
# 18239  004178535         BRACY TERRENCE L              EO00
# 18240  005182764           MASAYESVA,ANNA              EO00
# 18241  007648236            ENG,MICHAEL F              EO00
# 18242  008349026         MONTES,SOCORRO O              EO00
# 18243  008450156             KEYES,DALE L              EO00
# 18244  009222486     NAME WITHHELD BY OPM              EO00
# 18245  010695555        WELTER KRISTINE E              EO00
# 19071  007941297  NAME WITHHELD BY AGENCY              GE00
# 19072  009264215          QUINN WILLIAM W              GE00
# 19331  002049515  NAME WITHHELD BY AGENCY              GS13
# 19332  002309369  NAME WITHHELD BY AGENCY              GS13
# 19475  002842511            MCVAY,WILLIAM              GS28
# 19476  009872653  NAME WITHHELD BY AGENCY              GS28
# 19486  000692865         CONDON,KENNETH C              GX00
# 19487  005534145          GONYA,ANTHONY P              GX00
# 19488  006088016            SCOTT,DAVID K              GX00
# 19489  008407749           SCOTT,DONALD D              GX00
# 19490  001324508         DOLAN,DAVID MARK              GY00
# 19491  004296713     BANDURSKI,BRUCE LORD              GY00
# 19998  001673128           REES,MARY NOEL              HE31
# 19999  002055252     NAME WITHHELD BY OPM              HE31
# 20000  002678183            REID NOELLE E              HE31
# 20001  003129017              SHIRLEY R H              HE31
# 20002  007906300     ALEXANDER LAWRENCE M              HE31
# 20003  009504857         SARMIENTO EFRAIN              HE31
# 20004  010606019            RIOS, NANETTE              HE31
# 23393  001936327  NAME WITHHELD BY AGENCY              HU**
# 23394  006522342               DAWSON L A              HU**
# 23395  009265107  NAME WITHHELD BY AGENCY              HU**
# 23569  005718348  NAME WITHHELD BY AGENCY              HUTT
# 29828  003406189        MCALEER, EDWARD J              PC00
# 29952  000500241      SAMPSON FREDERICK C              RE00
# 55509  001534608         CARTER,JAMILLE A              VADC
# 55558  005524582            LUTES,LINDA H              VAHB
# 65940  001305289  NAME WITHHELD BY AGENCY              ZK00
# 65941  001906771       GALLEGOS GILBERT G              ZK00
# 65942  002197545       HINES,CARMELITA R.              ZK00
# 65943  002352015     NAME WITHHELD BY OPM              ZK00
# 65944  003783809          DAHLIN DONALD C              ZK00
# 65945  008786183         STEWART ROBERT M              ZK00
# 65946  009641067    MITCHELL,JACQUELINE A              ZK00
# 65947  010391140  NAME WITHHELD BY AGENCY              ZK00
# 65948  010853775     NAME WITHHELD BY OPM              ZK00
#
#       Accession/Separation Indicator  Effective Date (year)  \
# 2                                 SH                   2000
# 3                                 SF                   2000
# 5877                              SJ                   1999
# 5878                              SA                   1999
# 6139                              AA                   2000
# 6140                              SA                   2000
# 16632                             AD                   2000
# 18233                             AD                   2000
# 18234                             SC                   2000
# 18235                             AD                   2000
# 18236                             AD                   2000
# 18237                             SJ                   2000
# 18238                             SJ                   2000
# 18239                             AD                   1998
# 18240                             AD                   2000
# 18241                             AD                   2000
# 18242                             AD                   2000
# 18243                             AD                   2000
# 18244                             AD                   2000
# 18245                             SC                   2000
# 19071                             SJ                   1999
# 19072                             SJ                   1998
# 19331                             SC                   2000
# 19332                             AC                   2000
# 19475                             SA                   2000
# 19476                             SK                   2000
# 19486                             SJ                   1999
# 19487                             SJ                   1999
# 19488                             SJ                   1999
# 19489                             SJ                   1999
# 19490                             SC                   2000
# 19491                             SD                   2000
# 19998                             AD                   2000
# 19999                             SA                   2000
# 20000                             SJ                   2000
# 20001                             SD                   2000
# 20002                             SJ                   2000
# 20003                             SJ                   2000
# 20004                             SC                   2000
# 23393                             AA                   2000
# 23394                             AA                   2000
# 23395                             AC                   1999
# 23569                             AC                   2000
# 29828                             AD                   2000
# 29952                             SF                   2000
# 55509                             AD                   2000
# 55558                             AC                   2000
# 65940                             SC                   2000
# 65941                             SJ                   2000
# 65942                             SJ                   2000
# 65943                             SJ                   2000
# 65944                             SJ                   2000
# 65945                             SJ                   2000
# 65946                             SJ                   2000
# 65947                             SJ                   2000
# 65948                             SJ                   2000
#
#        Effective Date (month)  Effective Date (day)    Age Pay Plan Grade  \
# 2                           1                    28  50-54       EX    04
# 3                           1                    28  55-59       GS    13
# 5877                        8                    28  20-24       GS    03
# 5878                        8                    28  25-29       GS    11
# 6139                        2                    13  40-44       GS    11
# 6140                        1                     1  30-34       GS    07
# 16632                       1                     9  30-34       AD    00
# 18233                       3                    27  40-44       AD    00
# 18234                       1                     7  45-49       AD    00
# 18235                       1                     4  20-24       AD    00
# 18236                       1                     3  30-34       AD    00
# 18237                       1                     6  50-54       AD    00
# 18238                       1                     7  50-54       AD    00
# 18239                      10                     7  45-49       SR    00
# 18240                       1                    31  20-24       AD    00
# 18241                       3                    26  45-49       AD    00
# 18242                       3                     6  20-24       AD    00
# 18243                       1                    24  50-54       AD    00
# 18244                       1                    18  20-24       AD    00
# 18245                       1                    21  15-19       AD    00
# 19071                      12                     9  60-64       AD    00
# 19072                      10                    31    75+       AD    00
# 19331                       3                     1  35-39       GS    11
# 19332                       1                     3  40-44       GS    13
# 19475                       3                    11  35-39       GS    14
# 19476                       3                    18  60-64       GS    13
# 19486                      10                    16  45-49       GS    05
# 19487                      10                    16  30-34       GS    04
# 19488                      10                    16  30-34       WG    03
# 19489                      10                    16  60-64       GS    06
# 19490                       3                    10  45-49       GG    14
# 19491                       2                    29  55-59       GG    15
# 19998                       1                     2  30-34       GS    09
# 19999                       2                    13  40-44       GS    11
# 20000                       1                     8  20-24       GS    04
# 20001                       2                     1  65-69       GS    13
# 20002                       1                    19  20-24       GS    03
# 20003                       1                    14  20-24       GS    04
# 20004                       2                    13  20-24       GS    03
# 23393                       3                    12  30-34       GS    14
# 23394                       2                    13  45-49       GS    14
# 23395                       8                     1  25-29       GS    07
# 23569                       1                     2  30-34       GS    12
# 29828                       1                     3  45-49       CZ    15
# 29952                       3                    11  45-49       GS    09
# 55509                       1                     2  20-24       GS    04
# 55558                       3                    26  50-54       GS    12
# 65940                       2                    11  60-64       GS    15
# 65941                       2                    29  55-59       AD    00
# 65942                       3                     2  40-44       GS    11
# 65943                       2                    29  55-59       GS    15
# 65944                       2                    29  55-59       AD    00
# 65945                       2                    29  55-59       AD    00
# 65946                       3                     2  50-54       GS    11
# 65947                       2                    29  70-74       AD    00
# 65948                       2                    29  65-69       AD    00
#
#       LOS Level Duty Station Occupation Occupational Cateogy (PATCO)  \
# 2         10-14    #########       0401                            P
# 3         10-14    110010001       0341                            A
# 5877        1-2    110010001       0326                            C
# 5878        3-4    110010001       0360                            A
# 6139      15-19    #########       0341                            A
# 6140      10-14    110010001       0318                            C
# 16632      UNSP    110010001       0301                            A
# 18233      UNSP    040530019       0241                            A
# 18234       < 1    040530019       0301                            A
# 18235      UNSP    040530019       0301                            A
# 18236      UNSP    040530019       0301                            A
# 18237       1-2    040530019       0301                            A
# 18238       1-2    040530019       0301                            A
# 18239       3-4    110010001       0301                            A
# 18240      UNSP    040530019       0303                            C
# 18241     10-14    040530019       0301                            A
# 18242      UNSP    040530019       0303                            T
# 18243      UNSP    040530019       0301                            A
# 18244      UNSP    #########       0301                            A
# 18245      UNSP    040530019       0301                            A
# 19071     10-14    #########       0301                            A
# 19072       3-4    110010001       0301                            A
# 19331     15-19    #########       0301                            A
# 19332      UNSP    #########       0334                            A
# 19475     10-14    110010001       0334                            A
# 19476     20-24    #########       0334                            A
# 19486       3-4    233750003       0817                            T
# 19487       < 1    233750003       0817                            T
# 19488       < 1    233750003       3502                            B
# 19489       3-4    233750003       0817                            T
# 19490     25-29    CA8050000       1301                            P
# 19491       35+    110010001       0408                            P
# 19998      UNSP    531960033       0301                            A
# 19999     20-24    130280121       0334                            A
# 20000       < 1    171670031       0326                            C
# 20001       35+    294120095       0685                            A
# 20002       < 1    481730113       0326                            C
# 20003       < 1    481730113       0326                            C
# 20004       1-2    RQ0480000       0326                            C
# 23393     10-14    #########       1102                            P
# 23394     20-24    110010001       0301                            A
# 23395       3-4    #########       1102                            P
# 23569       3-4    #########       1101                            A
# 29828     25-29    PM1000000       0501                            A
# 29952     10-14    040170005       2003                            A
# 55509      UNSP    110010001       0599                            O
# 55558       5-9    110010001       0343                            A
# 65940     25-29    #########       0301                            A
# 65941       1-2    350030001       0301                            A
# 65942       5-9    110010001       0341                            A
# 65943     25-29    110010001       0905                            P
# 65944       1-2    462730027       0301                            A
# 65945       1-2    450520079       0301                            A
# 65946       1-2    110010001       0301                            A
# 65947       1-2    #########       0301                            A
# 65948       1-2    #########       0301                            A
#
#        Adjusted Basic Pay Type of Appointment Work Schedule
# 2                122400.0                  38             F
# 3                 69008.0                  10             F
# 5877              19668.0                  42             F
# 5878              40714.0                  10             F
# 6139              44148.0                  10             F
# 6140              33009.0                  10             F
# 16632             72000.0                  48             F
# 18233             75000.0                  38             F
# 18234             13566.0                  48             P
# 18235             33000.0                  48             F
# 18236             50000.0                  48             P
# 18237             35000.0                  48             F
# 18238             35000.0                  48             F
# 18239                 0.0                  46             I
# 18240             13566.0                  48             P
# 18241             68000.0                  48             F
# 18242             25000.0                  48             F
# 18243             70000.0                  48             F
# 18244             15600.0                  48             F
# 18245             13566.0                  48             I
# 19071                 0.0                  48             I
# 19072                 0.0                  46             I
# 19331             49845.0                  10             F
# 19332             60890.0                  10             F
# 19475             76750.0                  10             F
# 19476             77126.0                  10             F
# 19486             24702.0                  48             F
# 19487             22077.0                  48             F
# 19488             24584.0                  48             F
# 19489             27535.0                  48             F
# 19490             83575.0                  10             F
# 19491            101565.0                  10             F
# 19998             35359.0                  30             F
# 19999             43585.0                  10             F
# 20000             21648.0                  42             F
# 20001             77972.0                  10             F
# 20002             19850.0                  42             F
# 20003             21011.0                  42             F
# 20004             17015.0                  42             F
# 23393             71954.0                  10             F
# 23394             81546.0                  10             F
# 23395             31176.0                  10             F
# 23569             51204.0                  15             F
# 29828            102115.0                  36             F
# 29952             39184.0                  10             F
# 55509             20829.0                  **             P
# 55558             56324.0                  10             F
# 65940            107738.0                  48             F
# 65941            116100.0                  48             I
# 65942             54117.0                  48             F
# 65943            110028.0                  40             F
# 65944            116100.0                  48             I
# 65945            116100.0                  48             I
# 65946             42724.0                  48             F
# 65947            116100.0                  48             I
# 65948            116100.0                  48             I
