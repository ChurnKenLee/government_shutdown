# %%
import pandas as pd
import statsmodels

# %%
opm_dynamic_dir = '../rawdata/opm-federal-employment-data/data/1973-09-to-2014-06/non-dod/dynamic/'
opm_status_dir = '../rawdata/opm-federal-employment-data/data/1973-09-to-2014-06/non-dod/status/'

# %%
pd.read_fwf(opm_dynamic_dir + 'DEC1982.NONDOD.FO05M3.TXT')
# Out:
#        000870791ROVDER,GEORGE          AB00S  19821030  25-29GS09  \
# 0      004690750BARRETT GILBERT        AC00A  19821124  60-64SR00
# 1      007739503ORR ROY                AC00S  19821124  45-49SR00
# 2      007944239MURPHY WILLIAM J       AC00A  19821124  40-44SR00
# 3      009250132HUMBERGER EDWARD M     AC00A  19821012  35-39AD00
# 4      010146555CUTLER, LYNN G.        AC00S  19821124  40-44SR00
# ...                                      ...       ...        ...
# 77487  006209124BERRY,WILLIAM J, III   WR00S  19821031  25-29GS12
# 77488  007601217MAYWALT,TIMOTHY E      WR00S  19821031  30-34GS14
# 77489  007692500SMITH,JUDITH B         WR00S  19821031  35-39GS06
# 77490  007668733BEARDSLEY, KATE C.     WT00S  19821225  25-29EG00
# 77491  007949200PUGH,ARDITH R.         WT00A  19821114  35-39AD00
#
#         5-9FR39000000801P02700610F
# 0      UNSP1300900950301       48I
# 1       1-24817301130301 000000**I
# 2      UNSP3661100830301       48I
# ...
